# %% [markdown]
# <a href="https://colab.research.google.com/github/wavejumper3/Machine-Learning-349/blob/main/HW1/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My first notebook
# - made this to demonstrate how to use notebook
# - yippee
#
# ![image.png](data:image/png;base64,...)

# %%
x = 5

print(x)
# Out:
# 5
