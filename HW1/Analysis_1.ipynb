# %% [markdown]
# <a href="https://colab.research.google.com/github/wavejumper3/Machine-Learning-349/blob/main/HW1/Analysis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis
#
# ## 1
# The steps are as follows:
#
# **Moving from Github to Google Colab**
# 1. Download the raw file notebook from github
# 2. In Colab, `File` -> `Upload Notebook`, and find the notebook you downloaded in your files
#
# **Moving from Colab to Github**
# 1. In Colab, `File`->`Save a Copy to Github`
# 2. Select your repository.
# 3. Rename the file so it follows the correct path
#
# ## 2
# **They all ran correctly!** The only difference was that the speedup from Numpy vs native python list operations was different, but it varied quite a bit each time I ran it. I'd assume that's because google allocated me a different GPU from what you were using, as it wasn't even in the ballpark (35-60 times faster!).
#
# # 3
# I first made my repository with the Github Web Interface, by
# - moving to add a new repository
# - naming it
# - adding temporary files in each folder so they would be saved *(Interesting lesson: Git does **not** store empty folders, only files and their paths)*.
#
# I originally created it without a readme, so I pulled the repository to my computer with the command line, added a readme file, commited it, and pushed it back. I realized afterwards that that had been unneccesary, and made the rest of the readme files directly in the web interface.
# The hardest part of formatting was remembering to include the folder path in the name when pushing from collab.
#
# # 4
# We'll be doing a lot of programming in python, and you have to walk before you can run. It's like teaching someone arithmetic before going on to algebra. Example: I thought I "knew" python, but the data science portions (pandas and some of numpy) were entirely new to me.
# Also if you can't write code within a programming language, you certianly won't be writing any algorithms in it, either.
