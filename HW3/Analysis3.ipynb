# %% [markdown]
# <a href="https://colab.research.google.com/github/wavejumper3/Machine-Learning-349/blob/main/HW3/Analysis3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### What challenges did you encounter when loading and inspecting a raw external dataset from Kaggle compared to pre-packaged datasets, specifically regarding implicit data types like whitespace entries in TotalCharges?
#
# I'd say there weren't a lot of challenges. I just downloaded the dataset and then used it. The implicit data types were frustrating, though. You have to look more carefully to make sure its not "string containing a number" or something silly like that.
#
#
# ### How did you determine which columns required missing value imputation versus other data cleaning methods, and what strategy did you choose?
#
# There was one column that needed it, and the strategies i chose were Median and Most Frequent.
#
# ### Explain how the Scikit-Learn ColumnTransformer and Pipeline streamline the data preparation process and prevent data leakage across preprocessing and training steps.
#
# It makes it so each step is its own defined function, and then it gives you a way to put all those steps together into one larger function that does all of them in order.
#
# ### How did comparing StandardScaler versus MinMaxScaler impact your model training, convergence, or final evaluation metrics?
#
# I... was that a thing we had to do? Step 5 said to use the appropriate scaler - Minmax OR StandardScaler, and I chose the standard scaler. MinMax scaler is only really good if you're creating a neural network and your data has no outliers, otherwise it just compresses the majority of your data to be almost indistinguishable.
#
# ### How does configuring SGDClassifier(loss='log_loss') differ from standard linear classification models, and what advantages do probability outputs and ROC-AUC metrics provide when evaluating customer churn?
#
# It allows the model to have a confidene value alongside the prediction, which is useful for a buisness - knowing if a prediction is highly confident or "probably kinda sorta likely" tells you how much you should act on that information. The ROC-AUC metric is a valuation of how often your model is confident and correct - in this case, all splits will correctly pick a churn or non-churn customer from a set about 83% of the time.
#
# ### Based on your model coefficients or feature evaluation, which features show the strongest relationship with customer churn, and what operational business insights do these findings reveal?
#
# Tenure, Month-to-month contracts, and fiber optic internet were the strongest influences - the longer a customer is around, the less likely they are to leave. Monthly contract customers leave more often. And those with fiber optic internet also leave more often than those without. The first and last of those aren't immediately useful (not offering fiber optic internet would lose market share), but it does point towards the idea that a montly contract reminds customers monthly about their bills, which may suggest having more annual customers, so there's less thought about leaving.
