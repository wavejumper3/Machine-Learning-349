# %% [markdown]
# <a href="https://colab.research.google.com/github/wavejumper3/Machine-Learning-349/blob/main/HW2/Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis
#
# 1. So, there actually weren't too many issues in this case. I had no issues importing the CSV. There was some missing information, though, which did require fixing.
#
# 2. There was only one field that actually had missing values. The percentage of entries that had missing values was quite high, and might have caused issues with the dataset if it had been imputed, especially as it was a categorical group rather than numerical. This is actually explicitly written as code - I checked it and kept the check in, showing my reasoning for the next person in an industry situation.
# I chose to create a new group, "MISSING", because of this.
#
# 3. So, it allows you to create several different ways to clean data for use, and using multiple methods on a single dataset. Otherwise, I'd be splitting the dataset into smaller fragments, processing each, and putting it back together, which is just asking for me to forget a part or accidentally include the wrong column somewhere.
#
# 4. The strongest relatonship to `attack_detected` (other than itself) was `failed_logins`. The insight here is that attackers often fail to log in multiple times, and every connection that failed to log in more than twice was an attacker. This might imply attempting multiple attack methods to "see what works". I don't have the cybersecurity knowledge to give any great advice, but I'd suggest adding some sort of limit to consecutive failed login attempts.
